# %%
import sys
sys.path.append('../')

from utils.landmarks import visualize_landmarks


# To allow auto reload to this notebook after modifying any external file imported
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
visualize_landmarks(
    slice_index = 21,
    subject = "copd4",
)

# %% [markdown]
# Slice 25/27 from copd2 has landmarks outside the segmentation mask.

# %%
from ipywidgets import interact, interactive, fixed, interact_manual, Layout
import ipywidgets as widgets

widget_width = '100px'

interact(visualize_landmarks, 
        slice_index = widgets.IntSlider(min=0, max=121, step=1, value=75),
        subject=widgets.Dropdown(options=['copd1', 'copd2', 'copd3', 'copd4'], value='copd1'),
        layout=Layout(width=widget_width)
)
# Out:
# interactive(children=(IntSlider(value=75, description='slice_index', max=121), Dropdown(description='subject',…
# <function utils.landmarks.visualize_landmarks(slice_index=70, subject='copd1')>
