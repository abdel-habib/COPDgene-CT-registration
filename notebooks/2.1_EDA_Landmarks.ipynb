# %%
import sys
sys.path.append('../')

from utils.landmarks import visualize_landmarks


# To allow auto reload to this notebook after modifying any external file imported
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
visualize_landmarks(
    landmarks_path='../dataset/train/copd1/copd1_300_eBH_xyz_r1.txt',
    reference_image_path='../dataset/train/copd1/copd1_eBHCT.nii.gz', # _lung
    slice_index = 70,
    voxel_dim = (0.625, 0.625, 2.5)
)

# still not functioning as expected, implement this with read_raw function
